# %%
driver = webdriver.Chrome()
driver.get("https://www.naukri.com/")
designation=driver.find_element(By.CLASS_NAME, "suggestor-input ")
designation.send_keys("Data Scientist")
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %% [markdown]
# Q1: In this question you have to scrape data using the filters available on the webpage You have to use the location and
# salary filter.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By 
import time

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title "]')
for i in title_tags():
    title=i.text
    job_title.append(title)
    
loc=driver.find_elements(By.XPATH,'//span[@class="locWdth"]')
for i in title_tags:
    loc=i.text
    job_location.append(loc)
    
name=driver.find_elements(By.XPATH,'//a[@class="comp-name mw-25"]')
for i in title_tags:
    name=i.text
    company_name.append(name)
    
exp=driver.find_elements(By.XPATH,'//span[@class="expwdth"]')
for i in title_tags:
    exp=i.text
    experience_required.append(title)
    
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 23 23 23 23

# %%
import pandas as pd
df=pd.DataFrame ({'Title':job_title,'Location':job_location, 'Company_name':company_name, 'Exp':experience_required})
df
# Out:
#                                                 Title  \
# 0                                Data Scientist - GCP
# 1                                      Data Scientist
# 2             Data Scientist: Artificial Intelligence
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5   Opportunity - NLP Data Scientist - Product bas...
# 6                                      Data Scientist
# 7      Business Intelligence Analyst (Data Scientist)
# 8                                      Data Scientist
# 9         Sr. Data Scientist & Machine Learning - AWS
# 10                                     Data Scientist
# 11                                     Data Scientist
# 12  Lead Data Scientist - Predictive Modeling & Ma...
# 13        Data Scientist + Gen AI - Immediate Joiners
# 14            Data Scientist: Artificial Intelligence
# 15            Data Scientist: Artificial Intelligence
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the
# job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
driver = webdriver.Chrome()
driver.get("https://www.shine.com/")
time.sleep(3)
job=driver.find_element(By.XPATH, '//li[@class="searchForm_search_item__hr6Du form-group "]')
job.send_keys("Data Analyst")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[19], line 4
#       2 driver.get("https://www.shine.com/")
#       3 time.sleep(3)
# ----> 4 job=driver.find_element(By.XPATH, '//li[@class="searchForm_search_item__hr6Du form-group "]')
#       5 job.send_keys("Data Analyst")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
# ...

# %% [markdown]
# Q3: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/apple-iphone-11-white-64-gb-includes-earpods-power-adapter/product-reviews/itm2644c3764fc54?pid=MOBFKCTSHAWGGFHM&lid=LSTMOBFKCTSHAWGGFHMS8ZLL1&marketplace=FLIPKART")

# %%
Rating = []
Review_summary = []
Full_review = []

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="XQDdHH Ga3i8K"]')
for i in title_tags:
    title=i.text
    Rating.append(title)
    
loc=driver.find_elements(By.XPATH,'//p[@class="z9E0IG"]')
for i in title_tags:
    loc=i.text
    Review_summary.append(loc)
    
name=driver.find_elements(By.XPATH,'//div[@class="ZmyHeo"]')
for i in title_tags:
    name=i.text
    Full_review.append(name)
    
print(len(Rating),len(Review_summary),len(Full_review))
# Out:
# 20 20 20

# %% [markdown]
# Q4: Scrape data forfirst 100 sneakers you find whenyouvisitflipkart.com and search for “sneakers” inthe search
# field.

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/")
sneakers=driver.find_element(By.CLASS_NAME, "Pke_EE")
sneakers.send_keys('sneakers')
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
Brand = []
ProductDescription = []
Price = []

# %%
brand=driver.find_elements(By.XPATH,'//div[@class="_2ABVdq"]')
for i in brand:
    title=i.text
    Brand.append(title)
    
productdescription=driver.find_elements(By.XPATH,'//a[@class="WKTcLC BwBZTg"]')
for i in productdescription:
    loc=i.text
    ProductDescription.append(loc)
    
price=driver.find_elements(By.XPATH,'//div[@class="Nx9bqj"]')
for i in price:
    name=i.text
    Price.append(name)
    
print(len(Rating),len(Review_summary),len(Full_review))
# Out:
# 20 20 20

# %%
import pandas as pd
df=pd.DataFrame ({'Brand_name':Brand,'Product_Description':ProductDescription, 'Price_inRS':Price,})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame ({'Brand_name':Brand,'Product_Description':ProductDescription, 'Price_inRS':Price,})
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...
